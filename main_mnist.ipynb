# %%
from utils.image_transformation import random_jitter
from utils.mnist_loader import get_mnist_data_set
from matplotlib import pyplot as plt

# %%
# get samples of images with digits '9' and '6' in correct format
X_6, X_9 = get_mnist_data_set()

# %%
# show a sample per digit

plt.figure(figsize=(8, 8))

plt.subplot(121)
plt.title('Sample for digit 6')
plt.imshow(X_6[0]/255.0)

plt.subplot(122)
plt.title('Sample for digit 9')
plt.imshow(X_9[0]/255.0)

# %%
# show a sample per digit with applied random jitter

new_image_9, image_9 = random_jitter(X_9[0], target_size=(28, 28), mirror=False)
new_image_6, image_6 = random_jitter(X_6[0], target_size=(28, 28), mirror=False)

plt.figure(figsize=(8, 8))

plt.subplot(221)
plt.title('Sample for digit 6 with random jitter')
plt.imshow(new_image_9/255.0)

plt.subplot(222)
plt.title('Original ample for digit 6')
plt.imshow(image_9/255.0)

plt.subplot(223)
plt.title('Sample for digit 9 with random jitter')
plt.imshow(new_image_6/255.0)

plt.subplot(224)
plt.title('Original ample for digit 9')
plt.imshow(image_6/255.0)
